# %%
import os
from pathlib import Path

from pycocotools.coco import COCO
import numpy as np
import cv2
import matplotlib.pyplot as plt

from src import ROOT_DIR
from src.datasets import MixedDataset
from src.utils import plot_tensor

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - Load COCO per dataset
# - make splits with cocosplit
# - Define dataset and dataloaders
# - Use the splits from coco to semantic masks as well for bildacher dataset

# %%
dataset = MixedDataset()

# %%
image = dataset[0]
image.shape
# Out:
# torch.Size([3, 1408, 2048])

# %%
plot_tensor(image)

# %%
cv2.imshow('image', image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B20.234.237.142/home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cv2.imshow('image', image)
#       <a href='vscode-notebook-cell://ssh-remote%2B20.234.237.142/home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> cv2.waitKey(0)
#
# error: OpenCV(4.8.1) /io/opencv/modules/highgui/src/window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
bboxes = dataset_dir / 'coco' / 'output.json'
images = dataset_dir / 'images'

#%%
coco = COCO(bboxes)

#%%
catIds = coco.getCatIds(catNms=['rumex_leaf']) #Add more categories ['person','dog']
imgIds = coco.getImgIds(catIds=catIds )
if not os.path.exists(seg_output_path):
    os.mkdir(original_img_path)
if not os.path.exists(original_img_path):
    os.mkdir(original_img_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B20.234.237.142/home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> bboxes = dataset_dir / 'coco' / 'output.json'
#       <a href='vscode-notebook-cell://ssh-remote%2B20.234.237.142/home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> images = dataset_dir / 'images'
#       <a href='vscode-notebook-cell://ssh-remote%2B20.234.237.142/home/azureuser/Alpine-Aster/notebook/prepare_data/pytorch_dataset_dev.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> #%%
#
# NameError: name 'dataset_dir' is not defined
